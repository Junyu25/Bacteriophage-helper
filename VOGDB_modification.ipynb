# %%
file = "/home/junyuchen/Lab/Phage-SOP/Database/VOGDB/vog.annotations.tsv"

# %%
Dir = "/home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified"

# %%
import os
import pandas as pd
df = pd.read_table(file)

# %%
df
# Out:
#       #GroupName  ProteinCount  SpeciesCount FunctionalCategory  \
# 0       VOG00001           743            36                 Xh
# 1       VOG00002           569            69                 Xh
# 2       VOG00003           704           161                 Xu
# 3       VOG00004           618           509                 Xu
# 4       VOG00005           877           689             XhXrXs
# ...          ...           ...           ...                ...
# 25395   VOG25396             2             2                 Xu
# 25396   VOG25397             2             2                 Xu
# 25397   VOG25398             2             2                 Xu
# 25398   VOG25399             2             2                 Xu
# 25399   VOG25400           271           271                 Xr
#
#                           ConsensusFunctionalDescription
# 0      sp|Q5UQJ2|YR863_MIMIV Putative ankyrin repeat ...
# 1      sp|Q9J4Z6|V244_FOWPN Putative ankyrin repeat p...
# ...

# %%
/home/junyu/Lab/Phage-SOP/Database/VOGDB/modified/VOG00001.hmm
/home/junyu/Lab/Phage-SOP/Database/VOGDB/modified/VOG00002.hmm
/home/junyu/Lab/Phage-SOP/Database/VOGDB/modified/VOG00003.hmm
/home/junyu/Lab/Phage-SOP/Database/VOGDB/modified/VOG00004.hmm
/home/junyu/Lab/Phage-SOP/Database/VOGDB/modified/VOG00005.hmm
/home/junyu/Lab/Phage-SOP/Database/VOGDB/modified/VOG00006.hmm
/home/junyu/Lab/Phage-SOP/Database/VOGDB/modified/VOG00007.hmm
/home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified

# %%
os.path.exists("/home/junyu/Lab/Phage-SOP/Database/VOGDB/modified/VOG00007.hmm")
# Out:
# False

# %%
Desc = df.ConsensusFunctionalDescription
for i in range(len(df)):
    hmm = os.path.join(Dir, df["#GroupName"][i]+".hmm")
    #print(hmm)
    if os.path.exists(hmm):
        #print(hmm)
        with open(hmm, "r") as in_file:
            buf = in_file.readlines()

        with open(hmm, "w") as out_file:
            for line in buf:
                if line == "NAME  " + df["#GroupName"][i] + "\n":
                    #print(line)
                    line = line + "DESC  " + Desc[i].split("|")[-1] + "\n"
                out_file.write(line)
# Out:
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00001.hmm
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00002.hmm
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00003.hmm
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00004.hmm
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00005.hmm
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00006.hmm
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00007.hmm
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00008.hmm
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00009.hmm
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00010.hmm
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00011.hmm
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00012.hmm
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00013.hmm
# /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00014.hmm
# ...

# %%
# !head /home/junyuchen/Lab/Phage-SOP/Database/VOGDB/modified/VOG00676.hmm
# Out:
# HMMER3/f [3.3 | Nov 2019]
# NAME  VOG00676
# DESC  REFSEQ hypothetical protein
# LENG  175
# ALPH  amino
# RF    no
# MM    no
# CONS  yes
# CS    no
# MAP   yes
