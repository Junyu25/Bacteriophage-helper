# %%
import pandas as pd

# %%
# !pwd
# Out:
# /home/junyuchen/Lab/Phage-SOP

# %%
df = pd.read_table("/home/junyuchen/Lab/Phage-SOP/Result/Annotations/CD1382_diamond.out", header=None)

# %% [markdown]
# * `qseqid` Query Seq - id
#
# * `sseqid` Subject Seq - id
#
# * `pident` Percentage of identical matches
#
# * `length` Alignment length
#
# * `mismatch` Number of mismatches
#
# * `gapopen` Number of gap openings
#
# * `qstart` Start of alignment in query
#
# * `qend` End of alignment in query
#
# * `sstart` Start of alignment in subject
#
# * `send` End of alignment in subject
#
# * `evalue` Expect value
#
# * `bitscore` Bit score

# %%
df.columns = ['a', 'b']
# Out:
#                                       0   \
# 0     NODE_1_length_167501_cov_42.904274
# 1    NODE_2_length_97655_cov_2546.011445
# 2    NODE_3_length_86889_cov_5793.294792
# 3      NODE_4_length_50225_cov_52.161272
# 4      NODE_5_length_29523_cov_98.038482
# ..                                   ...
# 266    NODE_293_length_144_cov_73.483146
# 267   NODE_295_length_126_cov_119.183099
# 268    NODE_296_length_125_cov_69.628571
# 269   NODE_297_length_108_cov_603.754717
# 270    NODE_298_length_98_cov_120.186047
#
#                                                     1      2     3    4   5   \
# 0    YP_009207440.1_long_tail_fiber_protein_[Escher...   84.4  1328  189   3
# 1    CRH63856.1_Uncharacterised_protein_[Chlamydia_...   48.0  2316  982  49
# 2    YP_009150149.1_DNA_polymerase_[Enterobacteriap...   99.6   909    4   0
# 3       WP_098593315.1_peptidase_S74_[Bacillus_cereus]   96.9  1781   56   0
# 4    ATN90897.1_terminase_large_subunit_[Propioniba...   97.6   503   12   0
# ..                                                 ...    ...   ...  ...  ..
# 266  YP_009151259.1_hypothetical_protein_[Escherich...  100.0    47    0   0
# 267  QBJ00670.1_DNA_polymerase_[Escherichia_phage_P...  100.0    41    0   0
# 268  NP_944801.1_Phage_conserved_protein_[Salmonell...  100.0    41    0   0
# 269  QBQ76264.1_hypothetical_protein_[Escherichia_p...   91.4    35    3   0
# 270  YP_009150149.1_DNA_polymerase_[Enterobacteriap...  100.0    32    0   0
#
#         6      7    8     9              10      11
# 0    56210  60160    1  1321   0.000000e+00  2243.8
# 1    67254  60607   49  2242   0.000000e+00  1941.8
# 2    51942  49216    1   909   0.000000e+00  1870.1
# 3    13467   8125    1  1781   0.000000e+00  3055.8
# 4      385   1893    1   503  7.800000e-281   979.9
# ..     ...    ...  ...   ...            ...     ...
# 266    143      3   62   108   7.000000e-19   102.1
# 267      2    124  801   841   1.300000e-13    84.3
# 268    123      1   86   126   9.800000e-14    84.7
# 269      3    107    5    39   1.100000e-08    67.8
# 270     96      1  835   866   1.600000e-11    77.0
#
# [271 rows x 12 columns]
